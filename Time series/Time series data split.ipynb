# %%
import pandas as pd

# %%
df = pd.read_csv('../occupancy_data/whole_data.csv').drop('Unnamed: 0', 1)

# %%
df
# Out:
#                       date  Temperature   Humidity       Light          CO2  \
# 0      2015-02-04 17:51:00    23.180000  27.272000  426.000000   721.250000
# 1      2015-02-04 17:51:59    23.150000  27.267500  429.500000   714.000000
# 2      2015-02-04 17:53:00    23.150000  27.245000  426.000000   713.500000
# 3      2015-02-04 17:54:00    23.150000  27.200000  426.000000   708.250000
# 4      2015-02-04 17:55:00    23.100000  27.200000  426.000000   704.500000
# 5      2015-02-04 17:55:59    23.100000  27.200000  419.000000   701.000000
# 6      2015-02-04 17:57:00    23.100000  27.200000  419.000000   701.666667
# 7      2015-02-04 17:57:59    23.100000  27.200000  419.000000   699.000000
# 8      2015-02-04 17:58:59    23.100000  27.200000  419.000000   689.333333
# 9      2015-02-04 18:00:00    23.075000  27.175000  419.000000   688.000000
# 10     2015-02-04 18:01:00    23.075000  27.150000  419.000000   690.250000
# ...

# %%
17895/100*70
# Out:
# 12526.5

# %%
17895/100*30
# Out:
# 5368.5

# %%
df_train = df[0:12527]

# %%
df_test = df[12528:]

# %%
df_train.to_csv('../occupancy_data/training_ts.csv')

# %%
df_test.to_csv('../occupancy_data/test_ts.csv')
